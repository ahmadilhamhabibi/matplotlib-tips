# %% [markdown]
# # Remove Spines

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = range(10)
y = [0, 3, 5, 4, 5, 7, 8, 8, 7, 9]

# %% [markdown]
# ## With matplotlib

# %%
plt.plot(x, y)
ax = plt.gca()
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False);

# %%
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
ax.spines
# Out:
# OrderedDict([('left', <matplotlib.spines.Spine at 0x1df6fbcde50>),
#              ('right', <matplotlib.spines.Spine at 0x1df6fbcdf40>),
#              ('bottom', <matplotlib.spines.Spine at 0x1df6fbe2040>),
#              ('top', <matplotlib.spines.Spine at 0x1df6fbe2130>)])

# %% [markdown]
# ### Remove all spines with ``set_frame_on``

# %%
plt.plot(x, y)
ax = plt.gca()
ax.set_frame_on(False);

# %% [markdown]
# ## Remove for all plots with ``rcParams``

# %%
plt.plot(x, y);

# %%
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False

# %%
plt.plot(x, y);

# %%
plt.scatter(x, y);

# %%
plt.rcParams['axes.spines.top'] = True
plt.rcParams['axes.spines.right'] = True

# %% [markdown]
# ## With Seaborn

# %%
plt.plot(x, y);

# %% [markdown]
# ### Removing other spines
#
# By default, ``sns.despine()`` removes top and left spines. Use arguments to update.
#
# Default: ``sns.despine(left=False, bottom=False, right=True, top=True)``

# %%
plt.plot(x, y)
sns.despine();

# %%
plt.plot(x, y)
sns.despine(left=True, right=False);
